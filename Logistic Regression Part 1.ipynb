# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df[['bought_insurance']])

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# c:\Users\victo\OneDrive\Documents\Data science course\machine-learning-1\env\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 0, 0, 1, 1, 1, 1])

# %%
model.score(X_test,y_test)
# Out:
# 0.8571428571428571

# %%
model.coef_
# Out:
# array([[0.14254986]])

# %%
model.intercept_
# Out:
# array([-5.50821904])
